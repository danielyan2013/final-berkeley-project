# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
print(os.getcwd())
# Out:
# /Users/tom_foolery312/Desktop/Project #3/Data

# %%
path = r'/Users/tom_foolery312/Desktop/Project #3/Data' # use your path
all_files = glob.glob(path + "/*.csv")
# cfb_data_to_load = "PrepSchool-2019PlayerRankings.csv"
# cfb_data_2000_df = pd.read_csv(cfb_data_to_load)

# %%
all_files
# Out:
# ['/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2002 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2003 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2000 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/HighSchool - 2020 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2007 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2006 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/HighSchool - 2021 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/HighSchool-2000PlayerRankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2005 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2004 Player Rankings.csv',
#  '/Users/tom_foolery312/Desktop/Project #3/Data/JUCO - 2010 Player Rankings.csv',
# ...

# %%
filename.split('-')[1][1:5]
# Out:
# '2015'

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['year']=filename.split('-')[1][1:5]
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.head(2000)
# Out:
#       ranking                 name  \
# 2266        1        D.J. Williams
# 2300       35         Sloan Thomas
# 2301       36         Raymond Mann
# 2302       37    Alphonso Townsend
# 2303       38           Greg Jones
# 2304       39         Chris Septak
# 2305       40         Paul Mociler
# 2306       41           Eric Knott
# 2307       42         Harold James
# 2308       43            Chris Rix
# 2309       44         Teyo Johnson
# 2310       45        Chris McKelvy
# 2311       46          Joe McGuire
# 2299       34          Antwan Odom
# 2312       47       Anthony Bryant
# 2314       49         Carlos Perez
# 2315       50          Adam Doiron
# 2316       51              Tre Orr
# 2317       52        Hobie Holiday
# 2318       53        Shannon Snell
# 2319       54        Larry Stevens
# 2320       55             Sam Ruhe
# 2321       56          Amon Gordon
# 2322       57            Steve Lee
# 2323       58       Reggie Vickers
# ...

# %%
frame.isna().sum()
# Out:
# ranking       3336
# name           107
# highSchool      92
# position        92
# height          92
# weight          92
# stars            0
# rating          92
# college          7
# year             0
# dtype: int64

# %%
frame.shape
# Out:
# (59061, 10)

# %%
3336*100/59061
# Out:
# 5.648397419617006

# %%
frame[frame['ranking'].isna()]
# Out:
#       ranking                   name  \
# 1507      NaN       Lamagea McDowell
# 1508      NaN           Jay Brunelle
# 1509      NaN            Zahir Swann
# 1510      NaN           Darius Jones
# 1511      NaN            Lonnie Rice
# 1512      NaN        Stefon Thompson
# 1513      NaN            Tyrell Ford
# 1514      NaN         Michael Frogge
# 1515      NaN            Trey Dawson
# 1516      NaN             Andrew Nee
# 1517      NaN         Ethan Hilliman
# 1518      NaN  Gabriel Hollingsworth
# 1519      NaN         Trevor Willard
# 1520      NaN          Eamonn Dennis
# 1521      NaN       Chavon McEachern
# 1522      NaN             Seth Jones
# 1523      NaN          Casey Filkins
# 1524      NaN          Thomas Dukart
# 1525      NaN             Shamir Bey
# 1526      NaN           Gavin Beerup
# 1527      NaN           Ke'shun Ford
# 1528      NaN       Deven Vanderbilt
# 1529      NaN           Justin Baker
# 1530      NaN        Rodney Robinson
# ...

# %%
frame['year']!= '2020'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 59031    True
# 59032    True
# 59033    True
# 59034    True
# 59035    True
# 59036    True
# 59037    True
# 59038    True
# 59039    True
# 59040    True
# 59041    True
# 59042    True
# 59043    True
# 59044    True
# 59045    True
# 59046    True
# 59047    True
# 59048    True
# 59049    True
# 59050    True
# 59051    True
# 59052    True
# 59053    True
# 59054    True
# 59055    True
# 59056    True
# 59057    True
# 59058    True
# 59059    True
# 59060    True
# ...

# %%
frame.sort_values(by='year', ascending=True, inplace=True)

# %%
frame.reset_index(inplace=True, drop=True)

# %%
frame.head(2000)
# Out:
#      ranking                   name  \
# 0          1          D.J. Williams
# 1        109       Stephen Williams
# 2          2           Brock Berlin
# 3        120  Nautyn McKay-Loescher
# 4        119           Marcus White
# 5        118       Dustin Picciotti
# 6        117          Lynn McGruder
# 7        116           Jason Witten
# 8        115           Doug Buckles
# 9        114           Cameron Wake
# 10       113           Jason Peters
# 11       112       Maurice Mitchell
# 12       111             Tatum Bell
# 13        63           Chris Boggas
# 14       110            John Rattay
# 15        94         Brandon Sumner
# 16       107           Ronnie Brown
# 17       106            Chris Young
# 18       105           Robert Peace
# 19       104           Chris Kelley
# 20       103           Willie Green
# 21       102            Ben Emanuel
# 22       101           Bennie Mills
# 23       100            Sean McHugh
# 24        99            Alex Barron
# ...

# %%
frame.to_csv('recruiting_cleandata.csv', sep=',')
