# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Pac12_summerized_crosstab.csv", encoding = "utf-16", delimiter = "\t", header = 0)

# %%
df = pd.DataFrame(data)

# %%
df = df.fillna(0)

# %%
df
# Out:
#               College  Year    1     2     3     4    5   Win%
# 0             Arizona  2006  0.0   9.0   8.0   3.0  0.0  0.444
# 1             Arizona  2007  0.0   6.0   4.0   2.0  0.0  0.444
# 2             Arizona  2008  0.0  11.0   4.0   4.0  0.0  0.556
# 3             Arizona  2009  0.0  15.0   3.0   1.0  0.0  0.667
# 4             Arizona  2010  1.0   8.0  10.0   1.0  0.0  0.444
# 5             Arizona  2011  0.0   8.0  14.0   0.0  0.0  0.222
# 6             Arizona  2012  0.0   2.0  21.0   2.0  0.0  0.444
# 7             Arizona  2013  0.0   2.0  24.0   1.0  0.0  0.444
# 8             Arizona  2014  0.0   4.0  24.0   4.0  0.0  0.778
# 9             Arizona  2015  0.0   0.0  24.0   1.0  0.0  0.333
# 10            Arizona  2016  0.0   2.0  14.0   2.0  0.0  0.111
# 11            Arizona  2017  0.0   3.0  24.0   1.0  0.0  0.556
# 12            Arizona  2018  0.0   0.0  20.0   0.0  0.0  0.444
# 13      Arizona State  2006  0.0  13.0   8.0   2.0  0.0  0.444
# ...

# %%
df.shape
# Out:
# (146, 8)

# %%
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\dyan\appdata\local\continuum\anaconda3\lib\site-packages (0.0)
# ...

# %%
# !pip install joblib

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
selected_features = df.drop(["College", "Year", "Win%"], axis = 1)

# %%
selected_features.head()
# Out:
#      1     2     3    4    5
# 0  0.0   9.0   8.0  3.0  0.0
# 1  0.0   6.0   4.0  2.0  0.0
# 2  0.0  11.0   4.0  4.0  0.0
# 3  0.0  15.0   3.0  1.0  0.0
# 4  1.0   8.0  10.0  1.0  0.0

# %%
y = df["Win%"]
X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=42)

# %%
X_train.head()
# Out:
#        1     2     3    4    5
# 84   0.0   0.0   5.0  6.0  3.0
# 68   0.0   6.0  24.0  0.0  0.0
# 51   0.0   9.0   6.0  7.0  1.0
# 135  3.0  18.0   5.0  0.0  0.0
# 134  1.0  14.0   5.0  1.0  0.0

# %%
#X_scaler = MinMaxScaler().fit(X_train)
#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.svm import SVR
model = SVR(kernel='linear')
model.fit(X_train, y_train)
predictions = model.predict(X_test)

print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
print(model)
# Out:
# Training Data Score: 0.16038939860187673
# Testing Data Score: 0.010335081153643011
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose = 3)

# %%
grid.fit(X_train, y_train)
# Out:
# C:\Users\dyan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...... C=1, gamma=0.0001, score=0.0891644405740416, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] .... C=1, gamma=0.0001, score=0.049999150580204765, total=   0.0s
# [CV] C=1, gamma=0.0001 ...............................................
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 1, 'gamma': 0.0001}
# -0.014611964347844685

# %%
#One Star Recruit
onestar = df["1"]
plt.scatter(onestar, y)
plt.show()

# %%
#One Star Recruit
twostar = df["2"]
plt.scatter(twostar, y)
plt.show()

# %%
threestar = df["3"]
plt.scatter(threestar, y)
plt.show()

# %%
fourstar = df["4"]
plt.scatter(fourstar, y)
plt.show()

# %%
fivestar = df["5"]
plt.scatter(fivestar, y)
plt.show()

# %%
data_lagged = pd.read_csv("Pac12_summerized_crosstab_lagged.csv", header = 0)

# %%
df_lagged = pd.df = pd.DataFrame(data_lagged)

# %%
df_lagged
# Out:
#               College  Year  1   2   3   4  5   Win%
# 0             Arizona  2006  0   9   8   3  0  0.556
# 1             Arizona  2007  0   6   4   2  0  0.667
# 2             Arizona  2008  0  11   4   4  0  0.444
# 3             Arizona  2009  0  15   3   1  0  0.222
# 4             Arizona  2010  1   8  10   1  0  0.444
# 5             Arizona  2011  0   8  14   0  0  0.444
# 6             Arizona  2012  0   2  21   2  0  0.778
# 7             Arizona  2013  0   2  24   1  0  0.333
# 8             Arizona  2014  0   4  24   4  0  0.111
# 9             Arizona  2015  0   0  24   1  0  0.556
# 10            Arizona  2016  0   2  14   2  0  0.444
# 11      Arizona State  2006  0  13   8   2  0  0.444
# 12      Arizona State  2007  0  17   4   3  0  0.222
# 13      Arizona State  2008  1  14   6   5  0  0.444
# 14      Arizona State  2009  2  13   5   1  1  0.444
# 15      Arizona State  2010  0  14  10   2  0  0.556
# 16      Arizona State  2011  0   1  12   0  0  0.889
# ...

# %%
selected_features_lagged = df_lagged.drop(["College", "Year", "Win%"], axis = 1)

# %%
y_lagged = df_lagged["Win%"]
X_train_lagged, X_test_lagged, y_train_lagged, y_test_lagged = train_test_split(selected_features_lagged, y_lagged, random_state=42)

# %%
model_lagged = SVR(kernel='linear')
model_lagged.fit(X_train_lagged, y_train_lagged)
predictions_lagged = model_lagged.predict(X_test_lagged)

print(f"Training Data Score: {model_lagged.score(X_train_lagged, y_train_lagged)}")
print(f"Testing Data Score: {model_lagged.score(X_test_lagged, y_test_lagged)}")
print(model_lagged)
# Out:
# Training Data Score: 0.07087115532740496
# Testing Data Score: 0.04668025623856498
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#One Star Recruit
onestar_lagged = df_lagged["1"]
plt.scatter(onestar_lagged, y_lagged)
plt.show()

# %%
twostar_lagged = df_lagged["2"]
plt.scatter(onestar_lagged, y_lagged)
plt.show()

# %%
threestar_lagged = df_lagged["3"]
plt.scatter(threestar_lagged, y_lagged)
plt.show()

# %%
fourstar_lagged = df_lagged["4"]
plt.scatter(fourstar_lagged, y_lagged)
plt.show()

# %%
fivestar_lagged = df_lagged["5"]
plt.scatter(fivestar_lagged, y_lagged)
plt.show()
